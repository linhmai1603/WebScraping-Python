# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import sys
from PyQt5.QtCore import QUrl
from PyQt5.QtWidgets import QApplication
from PyQt5.QtWebEngineWidgets import QWebEnginePage

# %%
job = "https://www.udel.edu/faculty-staff/human-resources/careers/faculty-jobs/"

# %%
html = urlopen(job)

# %%
page_content = bs(html, "html.parser")

# %%
table = page_content.find_all('table')[2]

# %%
tableTest = table.findAll('tr')

# %%
jobs = []

# %%
for tr in tableTest:
    td = tr.find_all('td')
    rows = [i.text.strip() for i in td]
    jobs.append(str(rows))

# %%
jobs = [str(job).replace('\xa0',' ') for job in jobs]
jobs = [str(job).replace('\\xa0',' ') for job in jobs]
jobs = [str(job).replace("['",' ') for job in jobs]
jobs = [str(job).replace("']",' ') for job in jobs]

# %%
links =[]
for aTag in table.findAll('a'):
    href = aTag.get('href')
    link = [i.text.strip() for i in href]
    ##rows = [i.text.strip() for i in href]
    links.append(str(link))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-74a76d5449d2> in <module>()
#       2 for aTag in table.findAll('a'):
#       3     href = aTag.get('href')
# ----> 4     link = [i.text.strip() for i in href]
#       5     ##rows = [i.text.strip() for i in href]
#       6     links.append(str(link))
#
# <ipython-input-25-74a76d5449d2> in <listcomp>(.0)
#       2 for aTag in table.findAll('a'):
#       3     href = aTag.get('href')
# ----> 4     link = [i.text.strip() for i in href]
#       5     ##rows = [i.text.strip() for i in href]
#       6     links.append(str(link))
#
# AttributeError: 'str' object has no attribute 'text'

# %%
class Client(QWebEnginePage):
    def __init__(self, url):
        self.app = QApplication(sys.argv)
        QWebEnginePage.__init__(self)
        self.html = ''
        self.loadFinished.connect(self._on_load_finished)
        self.load(QUrl(url))
        self.app.exec_()
    def _on_load_finished(self):
        self.html = self.toHtml(self.Callable)
        print('Load finished')

    def Callable(self, html_str):
        self.html = html_str
        self.app.quit()
url = Client("https://apply.interfolio.com/57342")
##client_response = Client(url)
##source = client_response.mainFrame().toHtml()
page_content = bs(url.html, "html.parser")
page_content
# Out:
# Load finished
# <!DOCTYPE html>
# <html class="ng-scope" lang="en" ng-app="apply" ng-controller="AppController as $ctrl" ng-strict-di="" xmlns:ng="http://angularjs.org"><head><style class="ng-binding" type="text/css">md-bottom-sheet.md-list md-list-item {    color: rgba(0,0,0,0.87);}md-bottom-sheet .md-subheader {    color: rgba(0,0,0,0.87);}a.md-button, .md-button {  border-radius: 3px;}a.md-button.md-icon-button, .md-button.md-icon-button {    border-radius: 50%;}a.md-button.md-primary, .md-button.md-primary {    color: rgb(63,81,181);}a.md-button.md-primary.md-raised, a.md-button.md-primary.md-fab, .md-button.md-primary.md-raised, .md-button.md-primary.md-fab {      color: rgba(255,255,255,0.87);      background-color: rgb(63,81,181);}a.md-button.md-primary.md-raised:not([disabled]) md-icon, a.md-button.md-primary.md-fab:not([disabled]) md-icon, .md-button.md-primary.md-raised:not([disabled]) md-icon, .md-button.md-primary.md-fab:not([disabled]) md-icon {        color: rgba(255,255,255,0.87);}a.md-button.md-primary.md-raised:not([disabled]):hover, a.md-button.md-primary.md-fab:not([disabled]):hover, .md-button.md-primary.md-raised:not([disabled]):hover, .md-button.md-primary.md-fab:not([disabled]):hover {        background-color: rgb(63,81,181);}a.md-button.md-primary.md-raised:not([disabled]).md-focused, a.md-button.md-primary.md-fab:not([disabled]).md-focused, .md-button.md-primary.md-raised:not([disabled]).md-focused, .md-button.md-primary.md-fab:not([disabled]).md-focused {        background-color: rgb(57,73,171);}a.md-button.md-primary:not([disabled]) md-icon, .md-button.md-primary:not([disabled]) md-icon {      color: rgb(63,81,181);}md-card .md-card-image {    border-radius: 2px 2px 0 0;}md-checkbox .md-icon {  border-color: rgba(0,0,0,0.54);}md-checkbox:not([disabled]).md-primary .md-ripple {  color: rgb(57,73,171);}md-checkbox:not([disabled]).md-primary.md-checked .md-ripple {  color: rgb(117,117,117);}md-checkbox:not([disabled]).md-primary .md-icon {  border-color: rgba(0,0,0,0.54);}md-checkbox:not([disabled]).md-primary.md-checked .md-icon {  background-color: rgba(63,81,181,0.87);}md-checkbox:not([disabled]).md-primary.md-checked.md-focused .md-container:before {  background-color: rgba(63,81,181,0.26);}md-checkbox:not([disabled]).md-primary.md-checked .md-icon:after {  border-color: rgb(238,238,238);}md-checkbox[disabled] .md-icon {  border-color: rgba(0,0,0,0.26);}md-checkbox[disabled] .md-label {  color: rgba(0,0,0,0.26);}md-chips .md-chips.md-focused {    box-shadow: 0 2px rgb(63,81,181);}md-chips .md-chip.md-focused {    background: rgb(63,81,181);    color: rgba(255,255,255,0.87);}md-chips .md-chip.md-focused md-icon {      color: rgba(255,255,255,0.87);}md-dialog.md-content-overflow .md-actions {    border-top-color: rgba(0,0,0,0.12);}md-divider {  border-top-color: rgba(0,0,0,0.12);}md-icon {  color: rgba(0,0,0,0.54);}md-icon.md-primary {    color: rgb(63,81,181);}md-input-container .md-input {  color: rgba(0,0,0,0.87);  border-color: rgba(0,0,0,0.12);  text-shadow: ;}md-input-container .md-input::-webkit-input-placeholder, md-input-container .md-input::-moz-placeholder, md-input-container .md-input:-moz-placeholder, md-input-container .md-input:-ms-input-placeholder {    color: rgba(0,0,0,0.26);}md-input-container > md-icon {  color: rgba(0,0,0,0.87);}md-input-container label, md-input-container .md-placeholder {  text-shadow: ;  color: rgba(0,0,0,0.26);}md-input-container:not(.md-input-invalid).md-input-has-value label {  color: rgba(0,0,0,0.54);}md-input-container:not(.md-input-invalid).md-input-focused .md-input {  border-color: rgb(63,81,181);}md-input-container:not(.md-input-invalid).md-input-focused label {  color: rgb(63,81,181);}md-input-container:not(.md-input-invalid).md-input-focused md-icon {  color: rgb(63,81,181);}md-list md-list-item.md-2-line .md-list-item-text h3, md-list md-list-item.md-2-line .md-list-item-text h4, md-list md-list-item.md-3-line .md-list-item-text h3, md-list md-list-item.md-3-line .md-list-item-text  ...
# <base href="/"/>
# <!--
#       The reasoning behind the double title is due to the fact that the browser
#       will load up the first title it sees. So if Angular has not yet loaded
#       and I try to do a standard default syntax: {{$ctrl.$state.current.data.pageTitle || 'String'}},
#       the title in the browser tab will actually output {{$ctrl.$state.current.data.pageTitle}} and it
#       just looks messy. This strategy below will display the first legitimate
#       title it sees, 'Apply - Interfolio', and then once Angular is ready, it
#       will update the title to be the proper one for the particular route. This
#       keeps the ugly curly braces from appearing for the first few seconds.
#     -->
# <!-- ngIf: !$ctrl.$state.current.data.pageTitle --><title class="ng-scope" ng-if="!$ctrl.$state.current.data.pageTitle">Apply - Interfolio</title><!-- end ngIf: !$ctrl.$state.current.data.pageTitle -->
# <!-- ngIf: $ctrl.$state.current.data.pageTitle -->
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <!-- Favicon Generated with: http://realfavicongenerator.net/ -->
# <link href="https://d3nh312v09acg2.cloudfront.net/public/images/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://d3nh312v09acg2.cloudfront.net/public/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://d3nh312v09acg2.cloudfront.net/public/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://d3nh312v09acg2.cloudfront.net/public/images/favicons/manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="https://d3nh312v09acg2.cloudfront.net/public/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#ffffff" name="theme-color"/>
# <!-- /Favicon -->
# <link href="https://fonts.googleapis.com/css?family=Raleway:400,500,600,700,400italic|Cabin:400,500,600,700,400italic" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.6.1/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/stylesheets/app.ca25e712.css" rel="stylesheet"/>
# <style></style><style>.cke{visibility:hidden;}</style><style type="text/css"></style></head>
# <body ng-attr-id="{{$ctrl.$state.current.data.pageId}}">
# <div class="spinner-overlay" ng-class="{'spinner-overlay': pageIsLoading}"></div>
# <a11y-sr-alerts class="ng-isolate-scope"><p aria-atomic="true" aria-live="assertive" class="a11y-offscreen intf-a11y-live-alerts" id="a11y-alerts"></p>
# </a11y-sr-alerts>
# <a class="sr-only sr-only-focusable" href="#content">
#       skip to main content
#     </a>
# <!-- ngIf: $ctrl.currentUser.isAuthenticated() || $ctrl.fisNavigation.skipAuthentication -->
# <div class="pad-bottom" id="fis-body-content" ng-class="{
#         'fis-sidebar-open': $ctrl.fisNavigation.sidebarOpen,
#       }">
# <!-- uiView: --><ui-view class="ng-scope" role="main"></ui-view>
# </div>
# <div class="modal-shim"></div>
# <script async="" src="//static.olark.com/jsclient/loader.js"></script><script src="/scripts/vendor.ca25e712.js"></script>
# <script src="/scripts/app.ca25e712.js"></script>
# <script src="/scripts/olark.ca25e712.js"></script>
# <iframe aria-hidden="true" data-olark="true" style="width: 0px; height: 0px; position: absolute; left: 0px; bottom: 0px; border: none;"></iframe></body></html>

# %%
divs
# Out:
# [<div class="spinner-overlay" ng-class="{'spinner-overlay': pageIsLoading}"></div>,
#  <div class="pad-bottom" id="fis-body-content" ng-class="{
#          'fis-sidebar-open': $ctrl.fisNavigation.sidebarOpen,
#        }">
#  <!-- uiView: --><ui-view class="ng-scope" role="main"></ui-view>
#  </div>,
#  <div class="modal-shim"></div>]

# %%
jobs_list = pd.DataFrame({'Job Title': jobs, 'Link': links})

# %%
jobs_list
# Out:
#                                             Job Title  \
# 0                        Assistant Professor, Syntax
# 1           School of Nursing, Senior Associate Dean
# 2    Assistant Professor Position in Coupled Human...
# 3    Tenured Associate Professor - Computer and In...
# 4    Tenure-Track Assistant Professor in Coastal E...
# 5     School of Nursing, Continuing Track Instructor
# 6                       Open Rank, Trumpet Professor
# 7    Faculty Position, Motor Speech, Communication...
# 8                        Open Rank, Violin Professor
# 9    Behavioral Health & Nutrition, Nutrition Clin...
# 10   Tenure-Track Assistant/Associate Professor in...
# 11           Assistant Professor of Sport Management
# 12   Faculty Position- Electrical & Computer Engin...
# 27   http://apply.interfolio.com/55462
# 28   http://apply.interfolio.com/52194
# 29   http://apply.interfolio.com/55352
# ..                                 ...
# 63   http://apply.interfolio.com/52639
# 64   http://apply.interfolio.com/52194
# 65   http://apply.interfolio.com/52538
# 66   http://apply.interfolio.com/52523
# 67   http://apply.interfolio.com/52356
# 68   http://apply.interfolio.com/51670
# 69   http://apply.interfolio.com/51663
# 70   http://apply.interfolio.com/51484
# 71   http://apply.interfolio.com/51413
# 72  https://apply.interfolio.com/51403
# 73  https://apply.interfolio.com/44873
# 74  https://apply.interfolio.com/50121
# 75   http://apply.interfolio.com/50102
# 76   http://apply.interfolio.com/49512
# 77   http://apply.interfolio.com/49081
# 78   http://apply.interfolio.com/49078
# 79   http://apply.interfolio.com/48978
# 80   http://apply.interfolio.com/48615
# 81   http://apply.interfolio.com/47186
# 82   http://apply.interfolio.com/47151
# 83   http://apply.interfolio.com/46626
# 84   http://apply.interfolio.com/46592
# 85   http://apply.interfolio.com/46428
# 86   http://apply.interfolio.com/46148
# 87   http://apply.interfolio.com/46144
# 88   http://apply.interfolio.com/46126
# 89   http://apply.interfolio.com/46121
# 90   http://apply.interfolio.com/45669
# 91   http://apply.interfolio.com/45555
# 92   http://apply.interfolio.com/43659
#
# [93 rows x 2 columns]

# %%
class Client(QWebEnginePage):
    def __init__(self, url):
        self.app = QApplication(sys.argv)
        QWebEnginePage.__init__(self)
        self.html = ''
        self.loadFinished.connect(self._on_load_finished)
        self.load(QUrl(url))
        self.app.exec_()
    def _on_load_finished(self):
        self.html = self.toHtml(self.Callable)
        print('Load finished')

    def Callable(self, html_str):
        self.html = html_str
        self.app.quit()
url = Client("https://gems.fastmail.usf.edu:4440/psc/gemspro-tam/EMPLOYEE/HRMS/c/HRS_HRAM.HRS_APP_SCHJOB.GBL?Page=HRS_APP_SCHJOB&Action=U&FOCUS=Applicant&SiteId=1&PortalActualURL=https%3a%2f%2fgems.fastmail.usf.edu%3a4440%2fpsc%2fgemspro-tam%2fEMPLOYEE%2fHRMS%2fc%2fHRS_HRAM.HRS_APP_SCHJOB.GBL%3fPage%3dHRS_APP_SCHJOB%26Action%3dU%26FOCUS%3dApplicant%26SiteId%3d1&PortalRegistryName=EMPLOYEE&PortalServletURI=https%3a%2f%2fgems.fastmail.usf.edu%3a4440%2fpsp%2fgemspro-tam%2f&PortalURI=https%3a%2f%2fgems.fastmail.usf.edu%3a4440%2fpsc%2fgemspro-tam%2f&PortalHostNode=HRMS&NoCrumbs=yes&PortalKeyStruct=yes")
##client_response = Client(url)
##source = client_response.mainFrame().toHtml()
page_content = bs(url.html, "html.parser")
job_table = page_content.find("table", {"class" : "PSLEVEL1GRID"})
# Out:
# Load finished

# %%
trs = job_table.findAll('tr')
trs
# Out:
# [<tr>
#  <th class="PSLEVEL1SSGRIDCOLUMNHDR" scope="col" width="18"> </th>
#  <th abbr="Job Title" align="left" class="PSLEVEL1SSGRIDCOLUMNHDR" scope="col" width="256"><a class="PSLEVEL1SSGRIDCOLUMNHDR" href="javascript:submitAction_win0(document.win0,'HRS_CE_JO_EXT_I$srt1$0');" id="HRS_CE_JO_EXT_I$srt1$0" name="HRS_CE_JO_EXT_I$srt1$0" tabindex="246" title="Click to sort ascending">Job Title</a></th>
#  <th abbr="Job ID" align="left" class="PSLEVEL1SSGRIDCOLUMNHDR" scope="col" width="47"><a class="PSLEVEL1SSGRIDCOLUMNHDR" href="javascript:submitAction_win0(document.win0,'HRS_CE_JO_EXT_I$srt2$0');" id="HRS_CE_JO_EXT_I$srt2$0" name="HRS_CE_JO_EXT_I$srt2$0" tabindex="247" title="Click to sort ascending">Job ID</a></th>
#  <th abbr="Location" align="left" class="PSLEVEL1SSGRIDCOLUMNHDR" scope="col" width="87"><a class="PSLEVEL1SSGRIDCOLUMNHDR" href="javascript:submitAction_win0(document.win0,'HRS_CE_JO_EXT_I$srt5$0');" id="HRS_CE_JO_EXT_I$srt5$0" name="HRS_CE_JO_EXT_I$srt5$0" tabindex="250" title="Click to sort ascending">Location</a></th>
#  <th abbr="VP Area" align="left" class="PSLEVEL1SSGRIDCOLUMNHDR" scope="col" width="107"><a class="PSLEVEL1SSGRIDCOLUMNHDR" href="javascript:submitAction_win0(document.win0,'HRS_CE_JO_EXT_I$srt6$0');" id="HRS_CE_JO_EXT_I$srt6$0" name="HRS_CE_JO_EXT_I$srt6$0" tabindex="251" title="Click to sort ascending">VP Area</a></th>
#  <th abbr="Department" align="left" class="PSLEVEL1SSGRIDCOLUMNHDR" scope="col" width="116"><a class="PSLEVEL1SSGRIDCOLUMNHDR" href="javascript:submitAction_win0(document.win0,'HRS_CE_JO_EXT_I$srt8$0');" id="HRS_CE_JO_EXT_I$srt8$0" name="HRS_CE_JO_EXT_I$srt8$0" tabindex="253" title="Click to sort ascending">Department</a></th>
#  <th abbr="Job Family" align="left" class="PSLEVEL1SSGRIDCOLUMNHDR" scope="col" width="87"><a class="PSLEVEL1SSGRIDCOLUMNHDR" href="javascript:submitAction_win0(document.win0,'HRS_CE_JO_EXT_I$srt10$0');" id="HRS_CE_JO_EXT_I$srt10$0" name="HRS_CE_JO_EXT_I$srt10$0" tabindex="255" title="Click to sort ascending">Job Family</a></th>
#  <th abbr="Posted Date" align="left" class="PSLEVEL1SSGRIDCOLUMNHDR" scope="col" width="40"><a class="PSLEVEL1SSGRIDCOLUMNHDR" href="javascript:submitAction_win0(document.win0,'HRS_CE_JO_EXT_I$srt15$0');" id="HRS_CE_JO_EXT_I$srt15$0" name="HRS_CE_JO_EXT_I$srt15$0" tabindex="260" title="Click to sort ascending">Posted Date</a></th>
#  <th abbr="Save Job" align="CENTER" class="PSLEVEL1SSGRIDCOLUMNHDR" scope="col" width="104">Save Job</th>
#  <th abbr="Apply" align="CENTER" class="PSLEVEL1SSGRIDCOLUMNHDR" scope="col" width="81">Apply</th>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row1" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row1');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row1');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row1');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 1 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$0"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$0"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$0');" id="POSTINGTITLE$0" name="POSTINGTITLE$0" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="267">Transit Bus Driver</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$0"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$0">19057</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$0"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$0">USF Tampa</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$0"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$0">Admin Svcs-Parking &amp; Trans</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$0"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$0">Parking and Transportation Svc</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$0"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$0">Staff</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$0"><span class="PSEDITBOX_DISPONLY" id="OPENED$0">11/09/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$0"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$0" name="HRS_SAVE_JOB_BTN2$0" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="275" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$0"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$0" name="HRS_CE_WRK_HRS_APPLY_PB$0" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="276" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row2" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row2');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row2');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row2');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 2 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$1"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$1"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$1');" id="POSTINGTITLE$1" name="POSTINGTITLE$1" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="280">Student Assistant, Transit Bus Driver</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$1"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$1">19056</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$1"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$1">USF Tampa</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$1"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$1">Admin Svcs-Parking &amp; Trans</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$1"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$1">Parking and Transportation Svc</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$1"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$1">Student Employment</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$1"><span class="PSEDITBOX_DISPONLY" id="OPENED$1">11/09/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$1"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$1" name="HRS_SAVE_JOB_BTN2$1" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="288" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$1"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$1" name="HRS_CE_WRK_HRS_APPLY_PB$1" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="289" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row3" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row3');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row3');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row3');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 3 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$2"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$2"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$2');" id="POSTINGTITLE$2" name="POSTINGTITLE$2" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="293">Unit Research Administrator</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$2"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$2">18492</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$2"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$2">USF Health</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$2"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$2">USFHealth-College of Medicine</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$2"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$2">Dept Of Internal Medicine</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$2"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$2">Administrative</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$2"><span class="PSEDITBOX_DISPONLY" id="OPENED$2">11/09/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$2"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$2" name="HRS_SAVE_JOB_BTN2$2" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="301" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$2"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$2" name="HRS_CE_WRK_HRS_APPLY_PB$2" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="302" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row4" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row4');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row4');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row4');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 4 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$3"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$3"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$3');" id="POSTINGTITLE$3" name="POSTINGTITLE$3" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="306">Administrative Specialist</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$3"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$3">19043</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$3"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$3">USF St. Petersburg</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$3"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$3">Acad Affairs-Fl Inst Oceanogr</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$3"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$3">Florida Institute Of Oceanogra</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$3"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$3">Staff</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED
span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$9"><span class="PSEDITBOX_DISPONLY" id="OPENED$9">11/08/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$9"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$9" name="HRS_SAVE_JOB_BTN2$9" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="392" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$9"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$9" name="HRS_CE_WRK_HRS_APPLY_PB$9" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="393" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row11" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row11');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row11');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row11');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 11 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$10"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$10"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$10');" id="POSTINGTITLE$10" name="POSTINGTITLE$10" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="397">Research Support Specialist</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$10"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$10">19033</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$10"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$10">USF Tampa</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$10"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$10">USFHealth-College of Medicine</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$10"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$10">Dept Of Neurology</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$10"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$10">Staff</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$10"><span class="PSEDITBOX_DISPONLY" id="OPENED$10">11/08/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$10"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$10" name="HRS_SAVE_JOB_BTN2$10" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="405" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$10"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$10" name="HRS_CE_WRK_HRS_APPLY_PB$10" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="406" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row12" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row12');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row12');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row12');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 12 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$11"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$11"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$11');" id="POSTINGTITLE$11" name="POSTINGTITLE$11" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="410">Academic Svc Administrator</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$11"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$11">19039</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$11"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$11">USF Health</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$11"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$11">USFHealth-College of Medicine</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$11"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$11">Dept Of Internal Medicine</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$11"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$11">Administrative</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$11"><span class="PSEDITBOX_DISPONLY" id="OPENED$11">11/08/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$11"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$11" name="HRS_SAVE_JOB_BTN2$11" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="418" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$11"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$11" name="HRS_CE_WRK_HRS_APPLY_PB$11" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="419" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row13" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row13');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row13');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row13');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 13 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$12"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$12"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$12');" id="POSTINGTITLE$12" name="POSTINGTITLE$12" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="423">FWS Student Assistant, Resource Management</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$12"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$12">19032</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$12"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$12">USF Tampa</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$12"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$12">Acad Affairs-Coll Engineering</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$12"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$12">Resource Management</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$12"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$12">FWS Student</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$12"><span class="PSEDITBOX_DISPONLY" id="OPENED$12">11/08/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$12"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$12" name="HRS_SAVE_JOB_BTN2$12" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="431" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$12"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$12" name="HRS_CE_WRK_HRS_APPLY_PB$12" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="432" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row14" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row14');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row14');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row14');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 14 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$13"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$13"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$13');" id="POSTINGTITLE$13" name="POSTINGTITLE$13" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="436">Associate Director of Development</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$13"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$13">18996</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$13"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$13">USF Tampa</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$13"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$13">Univ Advnc-Univ Advancement</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$13"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$13">University Advancement</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$13"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$13">Administrative</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$13"><span class="PSEDITBOX_DISPONLY" id="OPENED$13">11/08/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$13"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$13" name="HRS_SAVE_JOB_BTN2$13" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="444" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$13"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$13" name="HRS_CE_WRK_HRS_APPLY_PB$13" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="445" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row15" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row15');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row15');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row15');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 15 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$14"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$14"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$14');" id="POSTINGTITLE$14" name="POSTINGTITLE$14" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="449">Asst Director of Development, MCOM</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$14"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$14">19022</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$14"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$14">USF Health</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$14"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$14">USFHealth-Development</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$14"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$14">Health Development</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$14"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$14">Administrative</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$14"><span class="PSEDITBOX_DISPONLY" id="OPENED$14">11/08/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$14"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$14" name="HRS_SAVE_JOB_BTN2$14" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="457" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$14"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$14" name="HRS_CE_WRK_HRS_APPLY_PB$14" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="458" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row16" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row16');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row16');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row16');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 16 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$15"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$15"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$15');" id="POSTINGTITLE$15" name="POSTINGTITLE$15" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="462">Small Business Consultant (Sarasota/Manatee)</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$15"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$15">18811</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$15"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$15">USF Tampa</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$15"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$15">Acad Affairs-Coll of Business</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$15"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$15">Small Business Devlopment Ctr</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$15"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$15">Administrative</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$15"><span class="PSEDITBOX_DISPONLY" id="OPENED$15">11/08/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$15"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$15" name="HRS_SAVE_JOB_BTN2$15" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="470" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$15"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$15" name="HRS_CE_WRK_HRS_APPLY_PB$15" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="471" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row17" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row17');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row17');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row17');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 17 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
# ...
#  <div id="win0divHRS_LOCATION_DESCR$241"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$241">USF St. Petersburg</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$241"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$241">USFSP-Student Affairs</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$241"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$241">Student Affairs</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$241"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$241">Temporary</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$241"><span class="PSEDITBOX_DISPONLY" id="OPENED$241">01/10/2018</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$241"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$241" name="HRS_SAVE_JOB_BTN2$241" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="3408" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$241"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$241" name="HRS_CE_WRK_HRS_APPLY_PB$241" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="3409" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row243" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row243');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row243');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row243');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 243 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$242"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$242"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$242');" id="POSTINGTITLE$242" name="POSTINGTITLE$242" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="3413">Professor</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$242"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$242">15312</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$242"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$242">USF Health</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$242"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$242">USFHealth-College of Medicine</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$242"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$242">Dept Of Surgery</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$242"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$242">Faculty</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$242"><span class="PSEDITBOX_DISPONLY" id="OPENED$242">12/18/2017</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$242"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$242" name="HRS_SAVE_JOB_BTN2$242" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="3421" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$242"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$242" name="HRS_CE_WRK_HRS_APPLY_PB$242" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="3422" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row244" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row244');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row244');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row244');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 244 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$243"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$243"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$243');" id="POSTINGTITLE$243" name="POSTINGTITLE$243" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="3426">Assistant Professor to Professor</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$243"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$243">15291</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$243"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$243">USF Health</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$243"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$243">USFHealth-College of Medicine</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$243"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$243">Molecular Medicine</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$243"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$243">Faculty</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$243"><span class="PSEDITBOX_DISPONLY" id="OPENED$243">12/18/2017</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$243"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$243" name="HRS_SAVE_JOB_BTN2$243" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="3434" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$243"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$243" name="HRS_CE_WRK_HRS_APPLY_PB$243" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="3435" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row245" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row245');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row245');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row245');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 245 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$244"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$244"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$244');" id="POSTINGTITLE$244" name="POSTINGTITLE$244" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="3439">Lab Adjunct Faculty, Integrative Biology</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$244"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$244">15074</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$244"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$244">USF Tampa</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$244"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$244">Acad Affairs-Coll of Arts&amp;Sci</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$244"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$244">Integrative Biology</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$244"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$244">Temporary</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$244"><span class="PSEDITBOX_DISPONLY" id="OPENED$244">11/30/2017</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$244"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$244" name="HRS_SAVE_JOB_BTN2$244" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="3447" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$244"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$244" name="HRS_CE_WRK_HRS_APPLY_PB$244" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="3448" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row246" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row246');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row246');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row246');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 246 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$245"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$245"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$245');" id="POSTINGTITLE$245" name="POSTINGTITLE$245" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="3452">Assistant Professor</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$245"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$245">15003</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$245"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$245">USF Health</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$245"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$245">USFHealth-Coll of Pharmacy</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$245"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$245">Dept of Pharmacy Practice</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$245"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$245">Faculty</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$245"><span class="PSEDITBOX_DISPONLY" id="OPENED$245">11/20/2017</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$245"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$245" name="HRS_SAVE_JOB_BTN2$245" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="3460" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$245"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$245" name="HRS_CE_WRK_HRS_APPLY_PB$245" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="3461" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>,
#  <tr id="trHRS_CE_JO_EXT_I$0_row247" onclick="HighLightTR('rgb(238,238,238)','','trHRS_CE_JO_EXT_I$0_row247');" onmouseout="hoverLightTR('rgb(253,255,200)','',1,'trHRS_CE_JO_EXT_I$0_row247');" onmouseover="hoverLightTR('rgb(253,255,200)','',0,'trHRS_CE_JO_EXT_I$0_row247');" valign="center">
#  <td align="right" class="PSLEVEL1SSGRIDROW" height="17" scope="row"><span class="psaccesshidden">Row</span> 247 </td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divPOSTINGTITLE$246"><span class="PSHYPERLINKNOUL" id="POSTINGTITLE$span$246"><a class="PSHYPERLINKNOUL" href="javascript:submitAction_win0(document.win0,'POSTINGTITLE$246');" id="POSTINGTITLE$246" name="POSTINGTITLE$246" onclick="javascript:cancelBubble(event);" ptlinktgt="pt_peoplecode" tabindex="3465">Assistant/Associate In Research</a></span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOBNUMBER$246"><span class="PSEDITBOX_DISPONLY" id="JOBNUMBER$246">15011</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_LOCATION_DESCR$246"><span class="PSEDITBOX_DISPONLY" id="HRS_LOCATION_DESCR$246">USF Tampa</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divHRS_CE_JO_EXT_I_U_VP_AREA$246"><span class="PSDROPDOWNLIST_DISPONLY" id="HRS_CE_JO_EXT_I_U_VP_AREA$246">USFHealth-College of Medicine</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divU_PA_DEPT_VW_DESCR$164$$246"><span class="PSEDITBOX_DISPONLY" id="U_PA_DEPT_VW_DESCR$164$$246">Health Informatics Institute</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divJOB_FAMILY2$246"><span class="PSEDITBOX_DISPONLY" id="JOB_FAMILY2$246">Faculty</span>
#  </div></td>
#  <td align="left" class="PSLEVEL1SSGRIDROW">
#  <div id="win0divOPENED$246"><span class="PSEDITBOX_DISPONLY" id="OPENED$246">11/14/2017</span>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_SAVE_JOB_BTN2$246"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_SAVE_JOB_BTN2$246" name="HRS_SAVE_JOB_BTN2$246" onclick="submitAction_win0(document.win0,this.id,event);" style="width:104px; " tabindex="3473" type="button" value="Save Job"/></span></a>
#  </div></td>
#  <td align="CENTER" class="PSLEVEL1SSGRIDROW" style="white-space:nowrap;">
#  <div id="win0divHRS_CE_WRK_HRS_APPLY_PB$246"><a class="PSPUSHBUTTON" id="Left" role="presentation"><span style="background-Color: transparent;"><input class="PSPUSHBUTTON" id="HRS_CE_WRK_HRS_APPLY_PB$246" name="HRS_CE_WRK_HRS_APPLY_PB$246" onclick="submitAction_win0(document.win0,this.id,event);" style="width:81px; " tabindex="3474" title="Apply Results" type="button" value="Apply"/></span></a>
#  </div></td>
#  </tr>]

# %%
title = []
job_ids = []
locations = []
departments =[]
job_families = []
dates = []
vp_areas = []

# %%
for tr in trs:
    a = tr.find("a", {"class" : "PSHYPERLINKNOUL"})
    if(a is not None):
        title.append(str(a.text))

# %%
len(title)
# Out:
# 247

# %%
len(trs)
# Out:
# 248

# %%
i = -1
for tr in trs:
    ##print(tr)
    job_id = tr.find("span", id =("JOBNUMBER$" +str(i)))    
    ##print(job_id)
    if(job_id is not None):
        job_ids.append(str(job_id.text))
    location = tr.find("span",id = "HRS_LOCATION_DESCR$" +str(i))     
    if(location is not None):
        locations.append(str(location.text))
    vp_area = tr.find("span", id = "HRS_CE_JO_EXT_I_U_VP_AREA$" +str(i))     
    if(vp_area is not None):
         vp_areas.append(str(vp_area.text))    
    department = tr.find("span",id = "U_PA_DEPT_VW_DESCR$164$$" +str(i))     
    if(department is not None):
        departments.append(str(department.text))
    job_family = tr.find("span", id = "JOB_FAMILY2$"+str(i))     
    if(job_family is not None):
        job_families.append(str(job_family.text))
    date = tr.find("span", id ="OPENED$" +str(i))     
    if(date is not None):
        dates.append(str(date.text))    
    i +=1

# %%
len(job_ids)
# Out:
# 247

# %%
jobs_list = pd.DataFrame({'Job Title': title, 'ID': job_ids, 'Location' : locations, 'VP area' : vp_areas, 'Department' : departments, 'Job Family' : job_families, 'Open Date' : dates})

# %%
jobs_list
# Out:
#                                              Job Title     ID  \
# 0                                   Transit Bus Driver  19057
# 1                Student Assistant, Transit Bus Driver  19056
# 2                          Unit Research Administrator  18492
# 3                            Administrative Specialist  19043
# 4    New Student Connections - Digital Media Intern...  19046
# 5                             Data Collector (Student)  18995
# 6                      Business Operations Coordinator  19049
# 7     Assistant Professor, Department of Communication  18973
# 8                                  Assistant Professor  18994
# 9                       Marketing & Events Coordinator  19016
# 10                         Research Support Specialist  19033
# 11                          Academic Svc Administrator  19039
# 12          FWS Student Assistant, Resource Management  19032
# 13                   Associate Director of Development  18996
# 14                  Asst Director of Development, MCOM  19022
# 15        Small Business Consultant (Sarasota/Manatee)  18811
# 16                        Fiscal & Business Specialist  19031
# 17                                  Assistant Director  19040
# 18                             Computational Biologist  18827
# 19                    Sr Assoc AD - External Relations  19017
# 20                       Accounting Assistant - Travel  18201
# 21                     Director of Business Operations  19026
# 22   Instructor I - Rehabilitation & Mental Health ...  19012
# 23                 Associate Director of Business SGCS  19014
# 24                            Clerical and Secretarial  19004
# 25   Student Security Assistant - Contemporary Art ...  18976
# 26                                  Library Specialist  18948
# 27   FWS - Outdoor Maintenance Student Assistant - ...  19019
# 28                      Assistant Professor - Epilepsy  19011
# 29                                      Events Planner  19015
# ..                                                 ...    ...
# 217            Postdoctoral Scholar Research - Imaging  15106
# 218      Tenure-Track Faculty Geological Oceanographer  17208
# 219      Postdoctoral Scholar Research - Kidney Injury  16946
# 220                      Open Rank - Bariatric Surgery  17155
# 221     Assistant/Associate Professor - Rheumatologist   8661
# 222  Adult Gerontology Primary Care Nurse Practitio...  17116
# 223                                Assistant Professor  17113
# 224        Assistant Professor (Adult-Gero Acute Care)  17077
# 225                              Scientific Researcher  16057
# 226                 Instructor I - Procurement Surgeon  16787
# 227                     Associate Professor - Glaucoma  16017
# 228                         Assistant Professor - Pulm  16432
# 229                Open Rank - Lung Txp Pulmonologists  10214
# 230                      Assistant/Associate Professor  16191
# 231  Postdoctoral Scholar Research: Examining the R...  16295
# 232   Assistant Professor - Memory Disorder Specialist  16149
# 233                      Postdoctoral Scholar Research  16257
# 234  Open Rank (Assistant/Associate/Full Professor)...  16091
# 235            Assistant Professor - Retina Specialist  16012
# 236                      Postdoctoral Scholar Research  16173
# 237              Assistant Professor - Neuropsychology  16154
# 238                     Assistant Professor-Gen Ob/Gyn  15877
# 239                     Assistant Professor-Gen Ob/Gyn  15876
# 240           Assistant Professor - Dermatopathologist   6407
# 241                         Painter/General Facilities  15489
# 242                                          Professor  15312
# 243                   Assistant Professor to Professor  15291
# 244           Lab Adjunct Faculty, Integrative Biology  15074
# 245                                Assistant Professor  15003
# 246                    Assistant/Associate In Research  15011
#
#                Location                         VP area  \
# 0             USF Tampa      Admin Svcs-Parking & Trans
